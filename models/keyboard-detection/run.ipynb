# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/COMP4901J/models/keyboard-detection/'
# Out:
# /content/drive/My Drive/COMP4901J/models/keyboard-detection

# %%
import model
import dataset
import matplotlib.pyplot as plt
# Out:
# # of X_train: 13531
# # of X_test: 1371
# # of X_val: 864

# %%
# print several keyboard images with labels

for _type in ['train', 'test', 'val']:

    print(f'Samples from X_{_type}: ')

    fig, axarr = plt.subplots(1, 2, figsize=[16, 16])

    for i in range(0, 2):
        img, pts = dataset.get_sample(_type)
        img = dataset.show_labelled_image(img, pts)
        axarr[i].imshow(img)

    plt.show()
# Out:
# Samples from X_train:
# Samples from X_test:
# Samples from X_val:

# %%
# print several RESIZED keyboard images with labels

for images, labels in dataset.data_batch(batch_size=4, image_size=(224, 224), NCHW=False):
    
    fig, axarr = plt.subplots(1, 2, figsize=[16, 16])

    for i in range(0, 2):
        img = images[i]
        pts = labels[i]
        img = dataset.show_labelled_image(img, pts)
        axarr[i].imshow(img)

    plt.show()
    
    break

# %%
keyboard_model = model.keyboard_detection_net()
keyboard_model.train()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.torch/models/resnet18-5c106cde.pth
# 46827520it [00:00, 99863103.44it/s]
#   0%|          | 0/13531 [00:00<?, ?it/s]
# Epoch 1/5
# ----------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-33fe22d06923> in <module>()
#       1 keyboard_model = model.keyboard_detection_net()
# ----> 2 keyboard_model.train()
#
# /content/drive/My Drive/COMP4901J/models/keyboard-detection/model.py in train(self, batch_size, learning_rate, num_epochs)
#      60
#      61                         # forward
# ---> 62                         outputs = model(inputs)
#      63                         labels = torch.reshape(labels, [-1, 8])
#      64                         loss = criterion(outputs, labels)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     160         x = self.avgpool(x)
#     161         x = x.view(x.size(0), -1)
# --> 162         x = self.fc(x)
#     163
#     164         return x
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      65     @weak_script_method
#      66     def forward(self, input):
# ---> 67         return F.linear(input, self.weight, self.bias)
#      68
#      69     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1350     if input.dim() == 2 and bias is not None:
#    1351         # fused op is marginally faster
# -> 1352         ret = torch.addmm(torch.jit._unwrap_optional(bias), input, weight.t())
#    1353     else:
#    1354         output = input.matmul(weight.t())
#
# RuntimeError: Expected object of backend CPU but got backend CUDA for argument #4 'mat1'
