# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import dataset_t as dataset
batch = {
    'single': dataset.data_batch(size='single', NCHW=False), # default true
    'bundle': dataset.data_batch(size='bundle', NCHW=False)  # default true
}
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# get v050 of single
for i, (ws, bs) in enumerate(batch['single']):
    if i == 50:
        break
        

print(ws.shape, bs.shape)
# Out:
# (52, 106, 21, 3) (36, 106, 20, 3)

# %%
fig, ax = plt.subplots(1, 52, figsize=(15, 30))
for i in range(52):
    ax[i].imshow(ws[i])
    ax[i].axis('off')
    
plt.show()

# %%
fig, ax = plt.subplots(1, 36, figsize=(20, 30))
for i in range(36):
    ax[i].imshow(bs[i])
    ax[i].axis('off')
    
plt.show()

# %%
truth = cv2.imread('dataset/X_test/V0050.jpg')
truth = cv2.cvtColor(truth, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(truth)

# %%
# get v0100 of bundle
for i, (ws, bs) in enumerate(batch['bundle']):
    if i == 100:
        break
        

print(ws.shape, bs.shape)
# Out:
# (52, 106, 37, 3) (36, 106, 36, 3)

# %%
fig, ax = plt.subplots(1, 52, figsize=(15, 30))
for i in range(52):
    ax[i].imshow(ws[i])
    ax[i].axis('off')
    
plt.show()

# %%
fig, ax = plt.subplots(1, 36, figsize=(20, 30))
for i in range(36):
    ax[i].imshow(bs[i])
    ax[i].axis('off')
    
plt.show()

# %%
truth = cv2.imread('dataset/X_test/V0100.jpg')
truth = cv2.cvtColor(truth, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(truth)
